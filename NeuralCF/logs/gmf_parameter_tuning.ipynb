# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/recommender_system/NeuralCF/
# Out:
# /content/drive/MyDrive/recommender_system/NeuralCF

# %%
# !ls
# Out:
# models.py	   ncf.py	    neural_cf.ipynb  run.py
# ncf_finetuning.py  ncf_ratings.csv  __pycache__      training_evolution

# %%
# !pip install optuna

# %%
# !python ncf_finetuning.py
# Out:
# [I 2024-12-08 22:44:48,429] A new study created in memory with name: no-name-8c83dc6e-f138-422f-967f-b5b45c6b7586
# Best validation RMSE: 1.2179
# Epoch at which occurs: 30
# [I 2024-12-08 22:46:22,867] Trial 0 finished with value: 1.21785860274803 and parameters: {'embedding_dim_gmf': 5194, 'lr': 0.002967993581483, 'weight_decay': 7.319466257237657e-05, 'batch_size': 3213}. Best is trial 0 with value: 1.21785860274803.
# Best validation RMSE: 0.8639
# Epoch at which occurs: 3
# [I 2024-12-08 22:47:23,505] Trial 1 finished with value: 0.863898674254798 and parameters: {'embedding_dim_gmf': 1749, 'lr': 0.05290719739812711, 'weight_decay': 3.183343498322785e-06, 'batch_size': 1677}. Best is trial 1 with value: 0.863898674254798.
# Best validation RMSE: 1.0682
# Epoch at which occurs: 21
# ...
